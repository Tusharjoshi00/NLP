# %%
# name entity recognition
#words -- automatic predefined categories
##person
#location
#organization
#date
#time   
#money
#percentage

# %%
paragraph = """The Eiffel Tower, also known as the Iron Lady, is a globally recognized landmark in Paris, France. It was initially built for the 1889 World's Fair and was the tallest man-made structure in the world at the time. It has become a symbol of French ingenuity and a popular tourist destination, attracting millions of visitors annually. The Eiffel Tower, also known as the Iron Lady, is a globally recognized landmark in Paris, France. It was initially built for the 1889 World's Fair and was the tallest man-made structure in the world at the time. It has become a symbol of French ingenuity and a popular tourist destination, attracting millions of visitors annually. """

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
# sen = nltk.sent_tokenize(paragraph)  # Sentence tokenization
words = nltk.word_tokenize(paragraph)  # Word tokenization
tag_elements = nltk.pos_tag(words)  # Part-of-speech tagging

# %%
import nltk 
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_elements)  # Named entity recognition
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), (',', ','), ('also', 'RB'), ('known', 'VBN'), ('as', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Iron', 'NNP'), ('Lady', 'NNP')]), (',', ','), ('is', 'VBZ'), ('a', 'DT'), ('globally', 'RB'), ('recognized', 'VBN'), ('landmark', 'NN'), ('in', 'IN'), Tree('GPE', [('Paris', 'NNP')]), (',', ','), Tree('GPE', [('France', 'NNP')]), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('initially', 'RB'), ('built', 'VBN'), ('for', 'IN'), ('the', 'DT'), ('1889', 'CD'), ('World', 'NNP'), ("'s", 'POS'), ('Fair', 'NNP'), ('and', 'CC'), ('was', 'VBD'), ('the', 'DT'), ('tallest', 'JJS'), ('man-made', 'JJ'), ('structure', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('at', 'IN'), ('the', 'DT'), ('time', 'NN'), ('.', '.'), ('It', 'PRP'), ('has', 'VBZ'), ('become', 'VBN'), ('a', 'DT'), ('symbol', 'NN'), ('of', 'IN'), Tree('GPE', [('French', 'JJ')]), ('ingenuity', 'NN'), ('and', 'CC'), ('a', 'DT'), ('popular', 'JJ')
# ...
